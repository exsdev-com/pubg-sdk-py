# %%
import os
os.chdir("..")

# %%
from pubg_client import Client
PUBG_TOKEN = 'TOKEN'
pubg = Client(auth=PUBG_TOKEN)

# %%
samples = pubg.shards.samples(platform="steam")

# %%
samples
# Out:
# {'data': {'type': 'sample',
#   'id': '9f94563f-fa2c-4377-b1c1-ca2679eb2341',
#   'attributes': {'createdAt': '2022-05-22T00:00:00Z',
#    'titleId': 'bluehole-pubg',
#    'shardId': 'steam'},
#   'relationships': {'matches': {'data': [{'type': 'match',
#       'id': '9748a528-5dc6-4417-bbff-c5f7242bcc10'},
#      {'type': 'match', 'id': '85924ace-d883-4811-a6f3-8ff6aca5e785'},
#      {'type': 'match', 'id': '7653fb3a-b18f-4dac-8ae6-200dd1d98038'},
#      {'type': 'match', 'id': 'fd3d679b-4903-4e2a-8940-a21a8b770077'},
#      {'type': 'match', 'id': '1777c711-c44a-479d-8e05-cbd77e4eae58'},
#      {'type': 'match', 'id': '5b81ff90-2ebf-4bd6-a8a7-488238698af4'},
#      {'type': 'match', 'id': '14887762-9cda-47f3-a715-eed30ba98a9e'},
#      {'type': 'match', 'id': '44e53708-99f7-471d-a12a-ddc30678129d'},
#      {'type': 'match', 'id': '21240594-8033-4286-937b-2a4dee5d59df'},
#      {'type': 'match', 'id': '8c9d776b-75b2-457b-bc52-e5d95200a0ad'},
# ...
